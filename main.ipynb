# %%
import towhee
from data import source
towhee.read_csv(source).show()
# Out:
# <table style="border-collapse: collapse;"><tr><th style="text-align: center; font-size: 130%; border: none;">id</th> <th style="text-align: center; font-size: 130%; border: none;">path</th> <th style="text-align: center; font-size: 130%; border: none;">label</th></tr> <tr><td style="text-align: center; vertical-align: center; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">0</td> <td style="text-align: center; vertical-align: center; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">D:/data./train/brain_coral/n0191...</td> <td style="text-align: center; vertical-align: center; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">brain_coral</td></tr> <tr><td style="text-align: center; vertical-align: center; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">1</td> <td style="text-align: center; vertical-align: center; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">D:/data./train/brain_coral/n0191..
# ...

# %%
towhee.read_csv(source) \
    .head(2) \
    .image_decode.cv2['path', 'img']() \
    .show()
# Out:
# <table style="border-collapse: collapse;"><tr><th style="text-align: center; font-size: 130%; border: none;">id</th> <th style="text-align: center; font-size: 130%; border: none;">path</th> <th style="text-align: center; font-size: 130%; border: none;">label</th> <th style="text-align: center; font-size: 130%; border: none;">img</th></tr> <tr><td style="text-align: center; vertical-align: center; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">0</td> <td style="text-align: center; vertical-align: center; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">D:/data./train/brain_coral/n0191...</td> <td style="text-align: center; vertical-align: center; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">brain_coral</td> <td style="text-align: center; vertical-align: center; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; "><img src="data:image/jpeg;base64,..." width = "128px" height = "128px" style = "float:left; padding:
# ...
